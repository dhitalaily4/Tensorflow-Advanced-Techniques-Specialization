# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 240.3819 - y1_output_loss: 122.3615 - y2_output_loss: 116.4661 - y1_output_root_mean_squared_error: 11.0950 - y2_output_root_mean_squared_error: 10.8297 - val_loss: 54.1484 - val_y1_output_loss: 20.5676 - val_y2_output_loss: 32.8394 - val_y1_output_root_mean_squared_error: 4.5647 - val_y2_output_root_mean_squared_error: 5.7716
# Epoch 2/500
# 614/614 [==============================] - 0s 180us/sample - loss: 34.1723 - y1_output_loss: 13.1022 - y2_output_loss: 21.1320 - y1_output_root_mean_squared_error: 3.6137 - y2_output_root_mean_squared_error: 4.5949 - val_loss: 53.9577 - val_y1_output_loss: 14.8683 - val_y2_output_loss: 39.1494 - val_y1_output_root_mean_squared_error: 3.8698 - val_y2_output_root_mean_squared_error: 6.2436
# Epoch 3/500
# 614/614 [==============================] - 0s 173us/sample - loss: 24.2650 - y1_output_loss: 9.9201 - y2_output_loss: 14.1977 - y1_output_root_mean_squared_error: 3.1602 - y2_output_root_mean_squared_error: 3.7786 - val_loss: 22.6616 - val_y1_output_loss: 9.0332 - val_y2_output_loss: 13.6055 - val_y1_output_root_mean_squared_error: 3.0305 - val_y2_output_root_mean_squared_error: 3.6712
# Epoch 4/500
# 614/614 [==============================] - 0s 173us/sample - loss: 25.7570 - y1_output_loss: 10.1576 - y2_output_loss: 15.5715 - y1_output_root_mean_squared_error: 3.1740 - y2_output_root_mean_squared_error: 3.9601 - val_loss: 28.7173 - val_y1_output_loss: 11.8954 - val_y2_output_loss: 16.5724 - val_y1_output_root_mean_squared_error: 3.4782 - val_y2_output_root_mean_squared_error: 4.0767
# Epoch 5/500
# 614/614 [==============================] - 0s 178us/sample - loss: 24.3916 - y1_output_loss: 9.5991 - y2_output_loss: 14.8322 - y1_output_root_mean_squared_error: 3.0954 - y2_output_root_mean_squared_error: 3.8484 - val_loss: 27.0241 - val_y1_output_loss: 9.9495 - val_y2_output_loss: 16.8766 - val_y1_output_root_mean_squared_error: 3.1894 - val_y2_output_root_mean_squared_error: 4.1051
# Epoch 6/500
# 614/614 [==============================] - 0s 181us/sample - loss: 25.7934 - y1_output_loss: 9.9044 - y2_output_loss: 15.8907 - y1_output_root_mean_squared_error: 3.1495 - y2_output_root_mean_squared_error: 3.9843 - val_loss: 34.4631 - val_y1_output_loss: 10.5706 - val_y2_output_loss: 23.6386 - val_y1_output_root_mean_squared_error: 3.2865 - val_y2_output_root_mean_squared_error: 4.8644
# Epoch 7/500
# 614/614 [==============================] - 0s 187us/sample - loss: 22.1828 - y1_output_loss: 8.3827 - y2_output_loss: 13.9159 - y1_output_root_mean_squared_error: 2.8959 - y2_output_root_mean_squared_error: 3.7144 - val_loss: 69.4201 - val_y1_output_loss: 14.7162 - val_y2_output_loss: 54.8405 - val_y1_output_root_mean_squared_error: 3.8496 - val_y2_output_root_mean_squared_error: 7.3892
# Epoch 8/500
# 614/614 [==============================] - 0s 180us/sample - loss: 23.9956 - y1_output_loss: 9.4134 - y2_output_loss: 14.8449 - y1_output_root_mean_squared_error: 3.0521 - y2_output_root_mean_squared_error: 3.8315 - val_loss: 34.7864 - val_y1_output_loss: 9.1951 - val_y2_output_loss: 25.7133 - val_y1_output_root_mean_squared_error: 3.0510 - val_y2_output_root_mean_squared_error: 5.0475
# Epoch 9/500
# 614/614 [==============================] - 0s 172us/sample - loss: 20.3103 - y1_output_loss: 8.4281 - y2_output_loss: 12.0033 - y1_output_root_mean_squared_error: 2.8783 - y2_output_root_mean_squared_error: 3.4678 - val_loss: 20.8736 - val_y1_output_loss: 8.1052 - val_y2_output_loss: 12.6483 - val_y1_output_root_mean_squared_error: 2.8767 - val_y2_output_root_mean_squared_error: 3.5494
# Epoch 10/500
# 614/614 [==============================] - 0s 174us/sample - loss: 20.6997 - y1_output_loss: 8.3106 - y2_output_loss: 12.3920 - y1_output_root_mean_squared_error: 2.8834 - y2_output_root_mean_squared_error: 3.5193 - val_loss: 45.1144 - val_y1_output_loss: 12.2318 - val_y2_output_loss: 32.5133 - val_y1_output_root_mean_squared_error: 3.5355 - val_y2_output_root_mean_squared_error: 5.7109
# Epoch 11/500
# 614/614 [==============================] - 0s 163us/sample - loss: 20.9381 - y1_output_loss: 7.8971 - y2_output_loss: 13.3196 - y1_output_root_mean_squared_error: 2.8087 - y2_output_root_mean_squared_error: 3.6124 - val_loss: 67.0472 - val_y1_output_loss: 15.3718 - val_y2_output_loss: 51.0979 - val_y1_output_root_mean_squared_error: 3.9545 - val_y2_output_root_mean_squared_error: 7.1700
# Epoch 12/500
# 614/614 [==============================] - 0s 175us/sample - loss: 21.3229 - y1_output_loss: 7.8612 - y2_output_loss: 13.2797 - y1_output_root_mean_squared_error: 2.8149 - y2_output_root_mean_squared_error: 3.6605 - val_loss: 17.9519 - val_y1_output_loss: 6.7032 - val_y2_output_loss: 11.0719 - val_y1_output_root_mean_squared_error: 2.6268 - val_y2_output_root_mean_squared_error: 3.3245
# Epoch 13/500
# 614/614 [==============================] - 0s 176us/sample - loss: 20.6108 - y1_output_loss: 7.5860 - y2_output_loss: 12.9393 - y1_output_root_mean_squared_error: 2.7548 - y2_output_root_mean_squared_error: 3.6086 - val_loss: 24.9608 - val_y1_output_loss: 8.2654 - val_y2_output_loss: 16.3877 - val_y1_output_root_mean_squared_error: 2.9200 - val_y2_output_root_mean_squared_error: 4.0539
# Epoch 14/500
# 614/614 [==============================] - 0s 173us/sample - loss: 21.0818 - y1_output_loss: 8.0128 - y2_output_loss: 12.9702 - y1_output_root_mean_squared_error: 2.8288 - y2_output_root_mean_squared_error: 3.6166 - val_loss: 20.7684 - val_y1_output_loss: 8.4040 - val_y2_output_loss: 12.0903 - val_y1_output_root_mean_squared_error: 2.9306 - val_y2_output_root_mean_squared_error: 3.4900
# Epoch 15/500
# 614/614 [==============================] - 0s 161us/sample - loss: 18.5014 - y1_output_loss: 7.5842 - y2_output_loss: 10.8611 - y1_output_root_mean_squared_error: 2.7510 - y2_output_root_mean_squared_error: 3.3066 - val_loss: 28.3007 - val_y1_output_loss: 11.1233 - val_y2_output_loss: 17.0828 - val_y1_output_root_mean_squared_error: 3.3565 - val_y2_output_root_mean_squared_error: 4.1273
# Epoch 16/500
# 614/614 [==============================] - 0s 166us/sample - loss: 20.3955 - y1_output_loss: 7.5780 - y2_output_loss: 12.7533 - y1_output_root_mean_squared_error: 2.7450 - y2_output_root_mean_squared_error: 3.5862 - val_loss: 21.8803 - val_y1_output_loss: 10.2898 - val_y2_output_loss: 11.2702 - val_y1_output_root_mean_squared_error: 3.2409 - val_y2_output_root_mean_squared_error: 3.3730
# Epoch 17/500
# 614/614 [==============================] - 0s 178us/sample - loss: 17.2669 - y1_output_loss: 6.6487 - y2_output_loss: 10.4831 - y1_output_root_mean_squared_error: 2.5897 - y2_output_root_mean_squared_error: 3.2496 - val_loss: 19.6781 - val_y1_output_loss: 8.5061 - val_y2_output_loss: 10.7284 - val_y1_output_root_mean_squared_error: 2.9601 - val_y2_output_root_mean_squared_error: 3.3039
# Epoch 18/500
# 614/614 [==============================] - 0s 167us/sample - loss: 19.5795 - y1_output_loss: 7.3297 - y2_output_loss: 12.3426 - y1_output_root_mean_squared_error: 2.6890 - y2_output_root_mean_squared_error: 3.5141 - val_loss: 21.8822 - val_y1_output_loss: 6.3163 - val_y2_output_loss: 15.6685 - val_y1_output_root_mean_squared_error: 2.5280 - val_y2_output_root_mean_squared_error: 3.9359
# Epoch 19/500
# 614/614 [==============================] - 0s 168us/sample - loss: 20.6271 - y1_output_loss: 7.3902 - y2_output_loss: 13.2199 - y1_output_root_mean_squared_error: 2.7171 - y2_output_root_mean_squared_error: 3.6393 - val_loss: 27.2056 - val_y1_output_loss: 8.5884 - val_y2_output_loss: 18.6600 - val_y1_output_root_mean_squared_error: 2.9371 - val_y2_output_root_mean_squared_error: 4.3104
# Epoch 20/500
# 614/614 [==============================] - 0s 169us/sample - loss: 16.3555 - y1_output_loss: 6.2984 - y2_output_loss: 10.1289 - y1_output_root_mean_squared_error: 2.5042 - y2_output_root_mean_squared_error: 3.1756 - val_loss: 28.9263 - val_y1_output_loss: 8.4644 - val_y2_output_loss: 20.2827 - val_y1_output_root_mean_squared_error: 2.9415 - val_y2_output_root_mean_squared_error: 4.5027
# Epoch 21/500
# 614/614 [==============================] - 0s 155us/sample - loss: 16.2971 - y1_output_loss: 6.2356 - y2_output_loss: 10.0738 - y1_output_root_mean_squared_error: 2.4960 - y2_output_root_mean_squared_error: 3.1729 - val_loss: 16.8193 - val_y1_output_loss: 6.1175 - val_y2_output_loss: 10.6228 - val_y1_output_root_mean_squared_error: 2.4957 - val_y2_output_root_mean_squared_error: 3.2543
# Epoch 22/500
# 614/614 [==============================] - 0s 171us/sample - loss: 14.3827 - y1_output_loss: 5.6114 - y2_output_loss: 8.6814 - y1_output_root_mean_squared_error: 2.3757 - y2_output_root_mean_squared_error: 2.9562 - val_loss: 11.6988 - val_y1_output_loss: 4.9305 - val_y2_output_loss: 6.6463 - val_y1_output_root_mean_squared_error: 2.2443 - val_y2_output_root_mean_squared_error: 2.5810
# Epoch 23/500
# 614/614 [==============================] - 0s 168us/sample - loss: 15.8771 - y1_output_loss: 6.1918 - y2_output_loss: 9.6199 - y1_output_root_mean_squared_error: 2.4923 - y2_output_root_mean_squared_error: 3.1089 - val_loss: 14.5604 - val_y1_output_loss: 5.5761 - val_y2_output_loss: 8.6458 - val_y1_output_root_mean_squared_error: 2.3982 - val_y2_output_root_mean_squared_error: 2.9680
# Epoch 24/500
# 614/614 [==============================] - 0s 167us/sample - loss: 13.9493 - y1_output_loss: 5.3963 - y2_output_loss: 8.4419 - y1_output_root_mean_squared_error: 2.3300 - y2_output_root_mean_squared_error: 2.9190 - val_loss: 10.7897 - val_y1_output_loss: 4.1608 - val_y2_output_loss: 6.5207 - val_y1_output_root_mean_squared_error: 2.0688 - val_y2_output_root_mean_squared_error: 2.5514
# Epoch 25/500
# 614/614 [==============================] - 0s 178us/sample - loss: 14.2399 - y1_output_loss: 5.4745 - y2_output_loss: 8.7003 - y1_output_root_mean_squared_error: 2.3492 - y2_output_root_mean_squared_error: 2.9532 - val_loss: 14.5864 - val_y1_output_loss: 4.6261 - val_y2_output_loss: 9.7770 - val_y1_output_root_mean_squared_error: 2.1829 - val_y2_output_root_mean_squared_error: 3.1339
# Epoch 26/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.0025 - y1_output_loss: 5.0320 - y2_output_loss: 7.9505 - y1_output_root_mean_squared_error: 2.2417 - y2_output_root_mean_squared_error: 2.8244 - val_loss: 28.6554 - val_y1_output_loss: 8.9315 - val_y2_output_loss: 19.8473 - val_y1_output_root_mean_squared_error: 2.9887 - val_y2_output_root_mean_squared_error: 4.4411
# Epoch 27/500
# 614/614 [==============================] - 0s 166us/sample - loss: 12.6824 - y1_output_loss: 4.7920 - y2_output_loss: 7.7851 - y1_output_root_mean_squared_error: 2.1993 - y2_output_root_mean_squared_error: 2.8010 - val_loss: 10.8603 - val_y1_output_loss: 3.9392 - val_y2_output_loss: 6.7432 - val_y1_output_root_mean_squared_error: 2.0099 - val_y2_output_root_mean_squared_error: 2.6116
# Epoch 28/500
# 614/614 [==============================] - 0s 186us/sample - loss: 15.2318 - y1_output_loss: 5.2005 - y2_output_loss: 10.0693 - y1_output_root_mean_squared_error: 2.2826 - y2_output_root_mean_squared_error: 3.1657 - val_loss: 22.2942 - val_y1_output_loss: 8.3174 - val_y2_output_loss: 13.4124 - val_y1_output_root_mean_squared_error: 2.9156 - val_y2_output_root_mean_squared_error: 3.7139
# Epoch 29/500
# 614/614 [==============================] - 0s 168us/sample - loss: 12.5721 - y1_output_loss: 4.7802 - y2_output_loss: 7.7853 - y1_output_root_mean_squared_error: 2.1738 - y2_output_root_mean_squared_error: 2.8012 - val_loss: 11.9117 - val_y1_output_loss: 3.9076 - val_y2_output_loss: 7.9767 - val_y1_output_root_mean_squared_error: 1.9957 - val_y2_output_root_mean_squared_error: 2.8159
# Epoch 30/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.4319 - y1_output_loss: 4.2169 - y2_output_loss: 6.3349 - y1_output_root_mean_squared_error: 2.0334 - y2_output_root_mean_squared_error: 2.5094 - val_loss: 29.4466 - val_y1_output_loss: 8.2028 - val_y2_output_loss: 21.6212 - val_y1_output_root_mean_squared_error: 2.8472 - val_y2_output_root_mean_squared_error: 4.6195
# Epoch 31/500
# 614/614 [==============================] - 0s 165us/sample - loss: 12.1938 - y1_output_loss: 4.4261 - y2_output_loss: 7.7154 - y1_output_root_mean_squared_error: 2.1109 - y2_output_root_mean_squared_error: 2.7817 - val_loss: 9.3606 - val_y1_output_loss: 3.2720 - val_y2_output_loss: 5.9079 - val_y1_output_root_mean_squared_error: 1.8378 - val_y2_output_root_mean_squared_error: 2.4460
# Epoch 32/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.9088 - y1_output_loss: 4.0431 - y2_output_loss: 6.9879 - y1_output_root_mean_squared_error: 1.9928 - y2_output_root_mean_squared_error: 2.6339 - val_loss: 24.4720 - val_y1_output_loss: 6.6149 - val_y2_output_loss: 18.2008 - val_y1_output_root_mean_squared_error: 2.5545 - val_y2_output_root_mean_squared_error: 4.2363
# Epoch 33/500
# 614/614 [==============================] - 0s 175us/sample - loss: 10.5367 - y1_output_loss: 3.7722 - y2_output_loss: 6.6683 - y1_output_root_mean_squared_error: 1.9515 - y2_output_root_mean_squared_error: 2.5939 - val_loss: 12.3797 - val_y1_output_loss: 3.8194 - val_y2_output_loss: 8.4795 - val_y1_output_root_mean_squared_error: 1.9744 - val_y2_output_root_mean_squared_error: 2.9123
# Epoch 34/500
# 614/614 [==============================] - 0s 181us/sample - loss: 13.3011 - y1_output_loss: 4.2526 - y2_output_loss: 9.0596 - y1_output_root_mean_squared_error: 2.0680 - y2_output_root_mean_squared_error: 3.0041 - val_loss: 8.7461 - val_y1_output_loss: 3.5216 - val_y2_output_loss: 5.2578 - val_y1_output_root_mean_squared_error: 1.8969 - val_y2_output_root_mean_squared_error: 2.2689
# Epoch 35/500
# 614/614 [==============================] - 0s 165us/sample - loss: 12.0973 - y1_output_loss: 4.1783 - y2_output_loss: 7.8616 - y1_output_root_mean_squared_error: 2.0511 - y2_output_root_mean_squared_error: 2.8090 - val_loss: 9.4086 - val_y1_output_loss: 2.5392 - val_y2_output_loss: 6.8732 - val_y1_output_root_mean_squared_error: 1.6136 - val_y2_output_root_mean_squared_error: 2.6086
# Epoch 36/500
# 614/614 [==============================] - 0s 168us/sample - loss: 9.3135 - y1_output_loss: 3.1841 - y2_output_loss: 6.1561 - y1_output_root_mean_squared_error: 1.7801 - y2_output_root_mean_squared_error: 2.4789 - val_loss: 20.5831 - val_y1_output_loss: 6.0918 - val_y2_output_loss: 14.7359 - val_y1_output_root_mean_squared_error: 2.4562 - val_y2_output_root_mean_squared_error: 3.8144
# Epoch 37/500
# 614/614 [==============================] - 0s 168us/sample - loss: 9.0885 - y1_output_loss: 3.1831 - y2_output_loss: 5.8284 - y1_output_root_mean_squared_error: 1.7921 - y2_output_root_mean_squared_error: 2.4243 - val_loss: 7.1680 - val_y1_output_loss: 2.6826 - val_y2_output_loss: 4.4940 - val_y1_output_root_mean_squared_error: 1.6472 - val_y2_output_root_mean_squared_error: 2.1106
# Epoch 38/500
# 614/614 [==============================] - 0s 169us/sample - loss: 8.8126 - y1_output_loss: 2.8467 - y2_output_loss: 5.8888 - y1_output_root_mean_squared_error: 1.6940 - y2_output_root_mean_squared_error: 2.4378 - val_loss: 6.7968 - val_y1_output_loss: 2.1355 - val_y2_output_loss: 4.7174 - val_y1_output_root_mean_squared_error: 1.4637 - val_y2_output_root_mean_squared_error: 2.1574
# Epoch 39/500
# 614/614 [==============================] - 0s 174us/sample - loss: 7.9050 - y1_output_loss: 2.9498 - y2_output_loss: 5.0073 - y1_output_root_mean_squared_error: 1.7210 - y2_output_root_mean_squared_error: 2.2233 - val_loss: 8.0373 - val_y1_output_loss: 2.2933 - val_y2_output_loss: 5.9360 - val_y1_output_root_mean_squared_error: 1.5130 - val_y2_output_root_mean_squared_error: 2.3975
# Epoch 40/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.8431 - y1_output_loss: 2.8924 - y2_output_loss: 5.9475 - y1_output_root_mean_squared_error: 1.7070 - y2_output_root_mean_squared_error: 2.4350 - val_loss: 6.2433 - val_y1_output_loss: 2.0515 - val_y2_output_loss: 4.1730 - val_y1_output_root_mean_squared_error: 1.4477 - val_y2_output_root_mean_squared_error: 2.0365
# Epoch 41/500
# 614/614 [==============================] - 0s 168us/sample - loss: 8.3646 - y1_output_loss: 2.8587 - y2_output_loss: 5.4679 - y1_output_root_mean_squared_error: 1.6983 - y2_output_root_mean_squared_error: 2.3410 - val_loss: 7.3537 - val_y1_output_loss: 2.1348 - val_y2_output_loss: 5.1758 - val_y1_output_root_mean_squared_error: 1.4799 - val_y2_output_root_mean_squared_error: 2.2724
# Epoch 42/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.6507 - y1_output_loss: 2.6256 - y2_output_loss: 5.2767 - y1_output_root_mean_squared_error: 1.6103 - y2_output_root_mean_squared_error: 2.2489 - val_loss: 52.8185 - val_y1_output_loss: 16.4963 - val_y2_output_loss: 36.3463 - val_y1_output_root_mean_squared_error: 4.0711 - val_y2_output_root_mean_squared_error: 6.0204
# Epoch 43/500
# 614/614 [==============================] - 0s 179us/sample - loss: 9.1720 - y1_output_loss: 2.8024 - y2_output_loss: 6.4100 - y1_output_root_mean_squared_error: 1.6796 - y2_output_root_mean_squared_error: 2.5201 - val_loss: 31.8042 - val_y1_output_loss: 5.8379 - val_y2_output_loss: 25.9762 - val_y1_output_root_mean_squared_error: 2.4338 - val_y2_output_root_mean_squared_error: 5.0873
# Epoch 44/500
# 614/614 [==============================] - 0s 192us/sample - loss: 9.9206 - y1_output_loss: 3.0312 - y2_output_loss: 7.1442 - y1_output_root_mean_squared_error: 1.7417 - y2_output_root_mean_squared_error: 2.6243 - val_loss: 13.2100 - val_y1_output_loss: 3.3068 - val_y2_output_loss: 9.8279 - val_y1_output_root_mean_squared_error: 1.8334 - val_y2_output_root_mean_squared_error: 3.1383
# Epoch 45/500
# 614/614 [==============================] - 0s 168us/sample - loss: 7.4394 - y1_output_loss: 2.4953 - y2_output_loss: 4.9117 - y1_output_root_mean_squared_error: 1.5778 - y2_output_root_mean_squared_error: 2.2248 - val_loss: 7.6115 - val_y1_output_loss: 2.7765 - val_y2_output_loss: 4.8245 - val_y1_output_root_mean_squared_error: 1.6878 - val_y2_output_root_mean_squared_error: 2.1824
# Epoch 46/500
# 614/614 [==============================] - 0s 160us/sample - loss: 8.6058 - y1_output_loss: 2.7466 - y2_output_loss: 5.8111 - y1_output_root_mean_squared_error: 1.6634 - y2_output_root_mean_squared_error: 2.4164 - val_loss: 8.5631 - val_y1_output_loss: 2.5272 - val_y2_output_loss: 6.2603 - val_y1_output_root_mean_squared_error: 1.5837 - val_y2_output_root_mean_squared_error: 2.4607
# Epoch 47/500
# 614/614 [==============================] - 0s 157us/sample - loss: 7.6312 - y1_output_loss: 2.3895 - y2_output_loss: 5.1848 - y1_output_root_mean_squared_error: 1.5494 - y2_output_root_mean_squared_error: 2.2870 - val_loss: 5.1582 - val_y1_output_loss: 1.7238 - val_y2_output_loss: 3.4400 - val_y1_output_root_mean_squared_error: 1.3346 - val_y2_output_root_mean_squared_error: 1.8377
# Epoch 48/500
# 614/614 [==============================] - 0s 169us/sample - loss: 6.6993 - y1_output_loss: 2.2058 - y2_output_loss: 4.6743 - y1_output_root_mean_squared_error: 1.4642 - y2_output_root_mean_squared_error: 2.1343 - val_loss: 33.2268 - val_y1_output_loss: 9.7187 - val_y2_output_loss: 23.8781 - val_y1_output_root_mean_squared_error: 3.1075 - val_y2_output_root_mean_squared_error: 4.8549
# Epoch 49/500
# 614/614 [==============================] - 0s 173us/sample - loss: 7.9593 - y1_output_loss: 2.4320 - y2_output_loss: 5.6222 - y1_output_root_mean_squared_error: 1.5389 - y2_output_root_mean_squared_error: 2.3646 - val_loss: 35.6221 - val_y1_output_loss: 10.1015 - val_y2_output_loss: 26.2285 - val_y1_output_root_mean_squared_error: 3.1383 - val_y2_output_root_mean_squared_error: 5.0767
# Epoch 50/500
# 614/614 [==============================] - 0s 168us/sample - loss: 7.5177 - y1_output_loss: 2.1317 - y2_output_loss: 5.3441 - y1_output_root_mean_squared_error: 1.4621 - y2_output_root_mean_squared_error: 2.3195 - val_loss: 6.0665 - val_y1_output_loss: 2.3618 - val_y2_output_loss: 3.7945 - val_y1_output_root_mean_squared_error: 1.5446 - val_y2_output_root_mean_squared_error: 1.9185
# Epoch 51/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.0788 - y1_output_loss: 2.0302 - y2_output_loss: 4.0470 - y1_output_root_mean_squared_error: 1.4247 - y2_output_root_mean_squared_error: 2.0122 - val_loss: 7.6096 - val_y1_output_loss: 1.5352 - val_y2_output_loss: 6.2275 - val_y1_output_root_mean_squared_error: 1.2398 - val_y2_output_root_mean_squared_error: 2.4643
# Epoch 52/500
# 614/614 [==============================] - 0s 168us/sample - loss: 7.5012 - y1_output_loss: 2.3802 - y2_output_loss: 5.1098 - y1_output_root_mean_squared_error: 1.5397 - y2_output_root_mean_squared_error: 2.2651 - val_loss: 12.9387 - val_y1_output_loss: 4.4332 - val_y2_output_loss: 8.6148 - val_y1_output_root_mean_squared_error: 2.1143 - val_y2_output_root_mean_squared_error: 2.9100
# Epoch 53/500
# 614/614 [==============================] - 0s 162us/sample - loss: 6.6055 - y1_output_loss: 1.9022 - y2_output_loss: 4.6454 - y1_output_root_mean_squared_error: 1.3846 - y2_output_root_mean_squared_error: 2.1653 - val_loss: 7.2857 - val_y1_output_loss: 2.1911 - val_y2_output_loss: 5.0413 - val_y1_output_root_mean_squared_error: 1.4966 - val_y2_output_root_mean_squared_error: 2.2463
# Epoch 54/500
# 614/614 [==============================] - 0s 176us/sample - loss: 6.0535 - y1_output_loss: 1.9548 - y2_output_loss: 4.4232 - y1_output_root_mean_squared_error: 1.3513 - y2_output_root_mean_squared_error: 2.0561 - val_loss: 73.7357 - val_y1_output_loss: 22.8367 - val_y2_output_loss: 51.0367 - val_y1_output_root_mean_squared_error: 4.7818 - val_y2_output_root_mean_squared_error: 7.1323
# Epoch 55/500
# 614/614 [==============================] - 0s 177us/sample - loss: 8.7750 - y1_output_loss: 2.7422 - y2_output_loss: 5.9815 - y1_output_root_mean_squared_error: 1.6625 - y2_output_root_mean_squared_error: 2.4517 - val_loss: 5.4474 - val_y1_output_loss: 1.1993 - val_y2_output_loss: 4.2366 - val_y1_output_root_mean_squared_error: 1.1009 - val_y2_output_root_mean_squared_error: 2.0580
# Epoch 56/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.4048 - y1_output_loss: 1.9516 - y2_output_loss: 4.5158 - y1_output_root_mean_squared_error: 1.3892 - y2_output_root_mean_squared_error: 2.1154 - val_loss: 8.7555 - val_y1_output_loss: 3.0957 - val_y2_output_loss: 6.4230 - val_y1_output_root_mean_squared_error: 1.6663 - val_y2_output_root_mean_squared_error: 2.4452
# Epoch 57/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.6502 - y1_output_loss: 1.9165 - y2_output_loss: 4.6933 - y1_output_root_mean_squared_error: 1.3876 - y2_output_root_mean_squared_error: 2.1736 - val_loss: 4.9632 - val_y1_output_loss: 1.8424 - val_y2_output_loss: 3.4215 - val_y1_output_root_mean_squared_error: 1.3219 - val_y2_output_root_mean_squared_error: 1.7932
# Epoch 58/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.7953 - y1_output_loss: 2.2071 - y2_output_loss: 4.6354 - y1_output_root_mean_squared_error: 1.4854 - y2_output_root_mean_squared_error: 2.1422 - val_loss: 10.9030 - val_y1_output_loss: 3.6928 - val_y2_output_loss: 7.4443 - val_y1_output_root_mean_squared_error: 1.9098 - val_y2_output_root_mean_squared_error: 2.6936
# Epoch 59/500
# 614/614 [==============================] - 0s 165us/sample - loss: 6.6309 - y1_output_loss: 2.1090 - y2_output_loss: 4.5614 - y1_output_root_mean_squared_error: 1.4577 - y2_output_root_mean_squared_error: 2.1228 - val_loss: 6.9885 - val_y1_output_loss: 1.7511 - val_y2_output_loss: 5.1411 - val_y1_output_root_mean_squared_error: 1.3362 - val_y2_output_root_mean_squared_error: 2.2810
# Epoch 60/500
# 614/614 [==============================] - 0s 174us/sample - loss: 5.8161 - y1_output_loss: 1.7186 - y2_output_loss: 4.1191 - y1_output_root_mean_squared_error: 1.3147 - y2_output_root_mean_squared_error: 2.0218 - val_loss: 6.1325 - val_y1_output_loss: 1.9415 - val_y2_output_loss: 4.1176 - val_y1_output_root_mean_squared_error: 1.4109 - val_y2_output_root_mean_squared_error: 2.0352
# Epoch 61/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.3302 - y1_output_loss: 1.7961 - y2_output_loss: 4.4946 - y1_output_root_mean_squared_error: 1.3419 - y2_output_root_mean_squared_error: 2.1283 - val_loss: 4.6837 - val_y1_output_loss: 1.3410 - val_y2_output_loss: 3.3496 - val_y1_output_root_mean_squared_error: 1.1630 - val_y2_output_root_mean_squared_error: 1.8251
# Epoch 62/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.5034 - y1_output_loss: 1.5565 - y2_output_loss: 3.9168 - y1_output_root_mean_squared_error: 1.2518 - y2_output_root_mean_squared_error: 1.9840 - val_loss: 6.5338 - val_y1_output_loss: 1.0714 - val_y2_output_loss: 5.3970 - val_y1_output_root_mean_squared_error: 1.0466 - val_y2_output_root_mean_squared_error: 2.3320
# Epoch 63/500
# 614/614 [==============================] - 0s 168us/sample - loss: 10.5509 - y1_output_loss: 2.9575 - y2_output_loss: 7.5277 - y1_output_root_mean_squared_error: 1.7278 - y2_output_root_mean_squared_error: 2.7506 - val_loss: 10.9360 - val_y1_output_loss: 2.3156 - val_y2_output_loss: 8.4797 - val_y1_output_root_mean_squared_error: 1.5431 - val_y2_output_root_mean_squared_error: 2.9249
# Epoch 64/500
# 614/614 [==============================] - 0s 167us/sample - loss: 5.8754 - y1_output_loss: 1.6588 - y2_output_loss: 4.2282 - y1_output_root_mean_squared_error: 1.2908 - y2_output_root_mean_squared_error: 2.0516 - val_loss: 3.9560 - val_y1_output_loss: 1.1124 - val_y2_output_loss: 2.8962 - val_y1_output_root_mean_squared_error: 1.0577 - val_y2_output_root_mean_squared_error: 1.6844
# Epoch 65/500
# 614/614 [==============================] - 0s 177us/sample - loss: 4.5889 - y1_output_loss: 1.2807 - y2_output_loss: 3.3087 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.8159 - val_loss: 6.5635 - val_y1_output_loss: 1.6154 - val_y2_output_loss: 4.8508 - val_y1_output_root_mean_squared_error: 1.2806 - val_y2_output_root_mean_squared_error: 2.2189
# Epoch 66/500
# 614/614 [==============================] - 0s 181us/sample - loss: 4.9104 - y1_output_loss: 1.3133 - y2_output_loss: 3.6175 - y1_output_root_mean_squared_error: 1.1432 - y2_output_root_mean_squared_error: 1.8983 - val_loss: 4.2595 - val_y1_output_loss: 1.1799 - val_y2_output_loss: 3.1735 - val_y1_output_root_mean_squared_error: 1.0943 - val_y2_output_root_mean_squared_error: 1.7499
# Epoch 67/500
# 614/614 [==============================] - 0s 177us/sample - loss: 5.5317 - y1_output_loss: 1.5718 - y2_output_loss: 3.9284 - y1_output_root_mean_squared_error: 1.2518 - y2_output_root_mean_squared_error: 1.9912 - val_loss: 4.3327 - val_y1_output_loss: 1.1231 - val_y2_output_loss: 3.3485 - val_y1_output_root_mean_squared_error: 1.0577 - val_y2_output_root_mean_squared_error: 1.7928
# Epoch 68/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.8657 - y1_output_loss: 1.1298 - y2_output_loss: 2.7516 - y1_output_root_mean_squared_error: 1.0664 - y2_output_root_mean_squared_error: 1.6518 - val_loss: 4.7041 - val_y1_output_loss: 0.9309 - val_y2_output_loss: 3.8552 - val_y1_output_root_mean_squared_error: 0.9572 - val_y2_output_root_mean_squared_error: 1.9462
# Epoch 69/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.5523 - y1_output_loss: 0.9347 - y2_output_loss: 2.5918 - y1_output_root_mean_squared_error: 0.9704 - y2_output_root_mean_squared_error: 1.6157 - val_loss: 3.1158 - val_y1_output_loss: 0.6676 - val_y2_output_loss: 2.5211 - val_y1_output_root_mean_squared_error: 0.8050 - val_y2_output_root_mean_squared_error: 1.5709
# Epoch 70/500
# 614/614 [==============================] - 0s 193us/sample - loss: 4.7738 - y1_output_loss: 1.2815 - y2_output_loss: 3.4603 - y1_output_root_mean_squared_error: 1.1346 - y2_output_root_mean_squared_error: 1.8672 - val_loss: 4.2008 - val_y1_output_loss: 1.3289 - val_y2_output_loss: 2.8646 - val_y1_output_root_mean_squared_error: 1.1617 - val_y2_output_root_mean_squared_error: 1.6886
# Epoch 71/500
# 614/614 [==============================] - 0s 190us/sample - loss: 3.8321 - y1_output_loss: 0.9824 - y2_output_loss: 2.8296 - y1_output_root_mean_squared_error: 0.9935 - y2_output_root_mean_squared_error: 1.6867 - val_loss: 3.2827 - val_y1_output_loss: 0.9105 - val_y2_output_loss: 2.3974 - val_y1_output_root_mean_squared_error: 0.9524 - val_y2_output_root_mean_squared_error: 1.5413
# Epoch 72/500
# 614/614 [==============================] - 0s 170us/sample - loss: 4.0777 - y1_output_loss: 1.0634 - y2_output_loss: 2.9939 - y1_output_root_mean_squared_error: 1.0296 - y2_output_root_mean_squared_error: 1.7371 - val_loss: 3.1607 - val_y1_output_loss: 0.8904 - val_y2_output_loss: 2.2903 - val_y1_output_root_mean_squared_error: 0.9436 - val_y2_output_root_mean_squared_error: 1.5067
# Epoch 73/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.3162 - y1_output_loss: 1.2353 - y2_output_loss: 3.1222 - y1_output_root_mean_squared_error: 1.1077 - y2_output_root_mean_squared_error: 1.7576 - val_loss: 8.1904 - val_y1_output_loss: 2.4560 - val_y2_output_loss: 5.6699 - val_y1_output_root_mean_squared_error: 1.5789 - val_y2_output_root_mean_squared_error: 2.3870
# Epoch 74/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.5570 - y1_output_loss: 0.9075 - y2_output_loss: 2.6247 - y1_output_root_mean_squared_error: 0.9553 - y2_output_root_mean_squared_error: 1.6262 - val_loss: 3.9006 - val_y1_output_loss: 0.8509 - val_y2_output_loss: 3.1193 - val_y1_output_root_mean_squared_error: 0.9279 - val_y2_output_root_mean_squared_error: 1.7434
# Epoch 75/500
# 614/614 [==============================] - 0s 180us/sample - loss: 3.2796 - y1_output_loss: 0.7603 - y2_output_loss: 2.5309 - y1_output_root_mean_squared_error: 0.8724 - y2_output_root_mean_squared_error: 1.5870 - val_loss: 4.8949 - val_y1_output_loss: 0.8106 - val_y2_output_loss: 4.1520 - val_y1_output_root_mean_squared_error: 0.8893 - val_y2_output_root_mean_squared_error: 2.0258
# Epoch 76/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.9632 - y1_output_loss: 1.0346 - y2_output_loss: 2.9057 - y1_output_root_mean_squared_error: 1.0202 - y2_output_root_mean_squared_error: 1.7095 - val_loss: 3.2137 - val_y1_output_loss: 0.7878 - val_y2_output_loss: 2.4368 - val_y1_output_root_mean_squared_error: 0.8913 - val_y2_output_root_mean_squared_error: 1.5554
# Epoch 77/500
# 614/614 [==============================] - 0s 162us/sample - loss: 4.4056 - y1_output_loss: 1.1046 - y2_output_loss: 3.2874 - y1_output_root_mean_squared_error: 1.0477 - y2_output_root_mean_squared_error: 1.8188 - val_loss: 3.4909 - val_y1_output_loss: 0.8034 - val_y2_output_loss: 2.7195 - val_y1_output_root_mean_squared_error: 0.8990 - val_y2_output_root_mean_squared_error: 1.6379
# Epoch 78/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.4764 - y1_output_loss: 0.8101 - y2_output_loss: 2.6392 - y1_output_root_mean_squared_error: 0.9022 - y2_output_root_mean_squared_error: 1.6317 - val_loss: 3.7477 - val_y1_output_loss: 0.7441 - val_y2_output_loss: 3.0492 - val_y1_output_root_mean_squared_error: 0.8553 - val_y2_output_root_mean_squared_error: 1.7367
# Epoch 79/500
# 614/614 [==============================] - 0s 162us/sample - loss: 4.2505 - y1_output_loss: 1.1504 - y2_output_loss: 3.1638 - y1_output_root_mean_squared_error: 1.0750 - y2_output_root_mean_squared_error: 1.7592 - val_loss: 14.0381 - val_y1_output_loss: 2.2730 - val_y2_output_loss: 12.0895 - val_y1_output_root_mean_squared_error: 1.4754 - val_y2_output_root_mean_squared_error: 3.4440
# Epoch 80/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.4214 - y1_output_loss: 0.7872 - y2_output_loss: 2.6233 - y1_output_root_mean_squared_error: 0.8909 - y2_output_root_mean_squared_error: 1.6210 - val_loss: 3.4941 - val_y1_output_loss: 0.6072 - val_y2_output_loss: 2.9674 - val_y1_output_root_mean_squared_error: 0.7631 - val_y2_output_root_mean_squared_error: 1.7064
# Epoch 81/500
# 614/614 [==============================] - 0s 180us/sample - loss: 3.1816 - y1_output_loss: 0.8493 - y2_output_loss: 2.3326 - y1_output_root_mean_squared_error: 0.9125 - y2_output_root_mean_squared_error: 1.5326 - val_loss: 2.9699 - val_y1_output_loss: 0.7500 - val_y2_output_loss: 2.2286 - val_y1_output_root_mean_squared_error: 0.8653 - val_y2_output_root_mean_squared_error: 1.4904
# Epoch 82/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.7998 - y1_output_loss: 1.0148 - y2_output_loss: 2.7662 - y1_output_root_mean_squared_error: 1.0120 - y2_output_root_mean_squared_error: 1.6660 - val_loss: 2.6520 - val_y1_output_loss: 0.4970 - val_y2_output_loss: 2.1674 - val_y1_output_root_mean_squared_error: 0.6976 - val_y2_output_root_mean_squared_error: 1.4715
# Epoch 83/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.8244 - y1_output_loss: 0.7505 - y2_output_loss: 2.0599 - y1_output_root_mean_squared_error: 0.8660 - y2_output_root_mean_squared_error: 1.4403 - val_loss: 3.5400 - val_y1_output_loss: 0.5655 - val_y2_output_loss: 3.0372 - val_y1_output_root_mean_squared_error: 0.7443 - val_y2_output_root_mean_squared_error: 1.7280
# Epoch 84/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.2525 - y1_output_loss: 0.8225 - y2_output_loss: 2.4176 - y1_output_root_mean_squared_error: 0.9085 - y2_output_root_mean_squared_error: 1.5579 - val_loss: 4.3860 - val_y1_output_loss: 1.1846 - val_y2_output_loss: 3.3044 - val_y1_output_root_mean_squared_error: 1.0643 - val_y2_output_root_mean_squared_error: 1.8037
# Epoch 85/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.5070 - y1_output_loss: 0.9169 - y2_output_loss: 2.5675 - y1_output_root_mean_squared_error: 0.9587 - y2_output_root_mean_squared_error: 1.6087 - val_loss: 2.4178 - val_y1_output_loss: 0.4244 - val_y2_output_loss: 2.0179 - val_y1_output_root_mean_squared_error: 0.6442 - val_y2_output_root_mean_squared_error: 1.4152
# Epoch 86/500
# 614/614 [==============================] - 0s 176us/sample - loss: 3.3933 - y1_output_loss: 0.8428 - y2_output_loss: 2.5331 - y1_output_root_mean_squared_error: 0.9189 - y2_output_root_mean_squared_error: 1.5965 - val_loss: 4.4224 - val_y1_output_loss: 1.3764 - val_y2_output_loss: 3.0605 - val_y1_output_root_mean_squared_error: 1.1717 - val_y2_output_root_mean_squared_error: 1.7463
# Epoch 87/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.8496 - y1_output_loss: 1.0845 - y2_output_loss: 2.7583 - y1_output_root_mean_squared_error: 1.0461 - y2_output_root_mean_squared_error: 1.6599 - val_loss: 2.5805 - val_y1_output_loss: 0.8608 - val_y2_output_loss: 1.7397 - val_y1_output_root_mean_squared_error: 0.9263 - val_y2_output_root_mean_squared_error: 1.3124
# Epoch 88/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.6183 - y1_output_loss: 0.8675 - y2_output_loss: 2.7491 - y1_output_root_mean_squared_error: 0.9257 - y2_output_root_mean_squared_error: 1.6617 - val_loss: 3.7213 - val_y1_output_loss: 1.0332 - val_y2_output_loss: 2.7057 - val_y1_output_root_mean_squared_error: 1.0076 - val_y2_output_root_mean_squared_error: 1.6450
# Epoch 89/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.5317 - y1_output_loss: 0.9145 - y2_output_loss: 2.6000 - y1_output_root_mean_squared_error: 0.9562 - y2_output_root_mean_squared_error: 1.6178 - val_loss: 4.0924 - val_y1_output_loss: 0.6371 - val_y2_output_loss: 3.5083 - val_y1_output_root_mean_squared_error: 0.7921 - val_y2_output_root_mean_squared_error: 1.8614
# Epoch 90/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.9810 - y1_output_loss: 0.6880 - y2_output_loss: 2.2747 - y1_output_root_mean_squared_error: 0.8330 - y2_output_root_mean_squared_error: 1.5123 - val_loss: 2.7213 - val_y1_output_loss: 0.6195 - val_y2_output_loss: 2.1305 - val_y1_output_root_mean_squared_error: 0.7751 - val_y2_output_root_mean_squared_error: 1.4562
# Epoch 91/500
# 614/614 [==============================] - 0s 183us/sample - loss: 2.8908 - y1_output_loss: 0.7606 - y2_output_loss: 2.1559 - y1_output_root_mean_squared_error: 0.8748 - y2_output_root_mean_squared_error: 1.4579 - val_loss: 5.1225 - val_y1_output_loss: 1.1046 - val_y2_output_loss: 4.0155 - val_y1_output_root_mean_squared_error: 1.0507 - val_y2_output_root_mean_squared_error: 2.0046
# Epoch 92/500
# 614/614 [==============================] - 0s 180us/sample - loss: 2.7082 - y1_output_loss: 0.5499 - y2_output_loss: 2.1958 - y1_output_root_mean_squared_error: 0.7408 - y2_output_root_mean_squared_error: 1.4695 - val_loss: 8.9590 - val_y1_output_loss: 0.8016 - val_y2_output_loss: 8.1854 - val_y1_output_root_mean_squared_error: 0.8984 - val_y2_output_root_mean_squared_error: 2.8551
# Epoch 93/500
# 614/614 [==============================] - 0s 174us/sample - loss: 2.6687 - y1_output_loss: 0.6534 - y2_output_loss: 2.0480 - y1_output_root_mean_squared_error: 0.8093 - y2_output_root_mean_squared_error: 1.4191 - val_loss: 5.2047 - val_y1_output_loss: 0.7332 - val_y2_output_loss: 4.4583 - val_y1_output_root_mean_squared_error: 0.8554 - val_y2_output_root_mean_squared_error: 2.1150
# Epoch 94/500
# 614/614 [==============================] - 0s 178us/sample - loss: 2.9414 - y1_output_loss: 0.5945 - y2_output_loss: 2.3348 - y1_output_root_mean_squared_error: 0.7722 - y2_output_root_mean_squared_error: 1.5314 - val_loss: 2.7785 - val_y1_output_loss: 0.8110 - val_y2_output_loss: 1.9790 - val_y1_output_root_mean_squared_error: 0.8999 - val_y2_output_root_mean_squared_error: 1.4031
# Epoch 95/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.5613 - y1_output_loss: 0.6827 - y2_output_loss: 1.9036 - y1_output_root_mean_squared_error: 0.8277 - y2_output_root_mean_squared_error: 1.3697 - val_loss: 9.4022 - val_y1_output_loss: 1.3178 - val_y2_output_loss: 8.0693 - val_y1_output_root_mean_squared_error: 1.1538 - val_y2_output_root_mean_squared_error: 2.8409
# Epoch 96/500
# 614/614 [==============================] - 0s 180us/sample - loss: 3.9251 - y1_output_loss: 0.9836 - y2_output_loss: 2.9240 - y1_output_root_mean_squared_error: 0.9884 - y2_output_root_mean_squared_error: 1.7170 - val_loss: 2.2072 - val_y1_output_loss: 0.3852 - val_y2_output_loss: 1.8722 - val_y1_output_root_mean_squared_error: 0.6034 - val_y2_output_root_mean_squared_error: 1.3576
# Epoch 97/500
# 614/614 [==============================] - 0s 174us/sample - loss: 3.1521 - y1_output_loss: 0.7305 - y2_output_loss: 2.3958 - y1_output_root_mean_squared_error: 0.8580 - y2_output_root_mean_squared_error: 1.5543 - val_loss: 2.6659 - val_y1_output_loss: 0.6409 - val_y2_output_loss: 2.0369 - val_y1_output_root_mean_squared_error: 0.7938 - val_y2_output_root_mean_squared_error: 1.4268
# Epoch 98/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.5097 - y1_output_loss: 0.5555 - y2_output_loss: 1.9443 - y1_output_root_mean_squared_error: 0.7485 - y2_output_root_mean_squared_error: 1.3962 - val_loss: 2.3250 - val_y1_output_loss: 0.4161 - val_y2_output_loss: 1.9218 - val_y1_output_root_mean_squared_error: 0.6427 - val_y2_output_root_mean_squared_error: 1.3827
# Epoch 99/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.6617 - y1_output_loss: 0.6092 - y2_output_loss: 2.0542 - y1_output_root_mean_squared_error: 0.7703 - y2_output_root_mean_squared_error: 1.4382 - val_loss: 2.1711 - val_y1_output_loss: 0.6243 - val_y2_output_loss: 1.5895 - val_y1_output_root_mean_squared_error: 0.7860 - val_y2_output_root_mean_squared_error: 1.2463
# Epoch 100/500
# 614/614 [==============================] - 0s 179us/sample - loss: 3.4174 - y1_output_loss: 0.7585 - y2_output_loss: 2.6376 - y1_output_root_mean_squared_error: 0.8711 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 2.4183 - val_y1_output_loss: 0.6252 - val_y2_output_loss: 1.8059 - val_y1_output_root_mean_squared_error: 0.7749 - val_y2_output_root_mean_squared_error: 1.3483
# Epoch 101/500
# 614/614 [==============================] - 0s 213us/sample - loss: 2.5853 - y1_output_loss: 0.6251 - y2_output_loss: 1.9481 - y1_output_root_mean_squared_error: 0.7927 - y2_output_root_mean_squared_error: 1.3989 - val_loss: 3.1963 - val_y1_output_loss: 0.7556 - val_y2_output_loss: 2.4720 - val_y1_output_root_mean_squared_error: 0.8691 - val_y2_output_root_mean_squared_error: 1.5624
# Epoch 102/500
# 614/614 [==============================] - 0s 191us/sample - loss: 2.9279 - y1_output_loss: 0.6939 - y2_output_loss: 2.2168 - y1_output_root_mean_squared_error: 0.8353 - y2_output_root_mean_squared_error: 1.4934 - val_loss: 3.9988 - val_y1_output_loss: 0.6700 - val_y2_output_loss: 3.4073 - val_y1_output_root_mean_squared_error: 0.8082 - val_y2_output_root_mean_squared_error: 1.8291
# Epoch 103/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.7738 - y1_output_loss: 0.6667 - y2_output_loss: 2.1252 - y1_output_root_mean_squared_error: 0.8022 - y2_output_root_mean_squared_error: 1.4595 - val_loss: 4.7584 - val_y1_output_loss: 1.8771 - val_y2_output_loss: 2.8887 - val_y1_output_root_mean_squared_error: 1.3737 - val_y2_output_root_mean_squared_error: 1.6945
# Epoch 104/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.9578 - y1_output_loss: 0.6694 - y2_output_loss: 2.2745 - y1_output_root_mean_squared_error: 0.8170 - y2_output_root_mean_squared_error: 1.5134 - val_loss: 2.5524 - val_y1_output_loss: 0.6180 - val_y2_output_loss: 1.9458 - val_y1_output_root_mean_squared_error: 0.7885 - val_y2_output_root_mean_squared_error: 1.3895
# Epoch 105/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.3971 - y1_output_loss: 0.5629 - y2_output_loss: 1.8912 - y1_output_root_mean_squared_error: 0.7501 - y2_output_root_mean_squared_error: 1.3544 - val_loss: 7.2810 - val_y1_output_loss: 1.7574 - val_y2_output_loss: 5.3586 - val_y1_output_root_mean_squared_error: 1.3330 - val_y2_output_root_mean_squared_error: 2.3461
# Epoch 106/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.1061 - y1_output_loss: 0.6835 - y2_output_loss: 2.3993 - y1_output_root_mean_squared_error: 0.8301 - y2_output_root_mean_squared_error: 1.5547 - val_loss: 2.1126 - val_y1_output_loss: 0.4695 - val_y2_output_loss: 1.6374 - val_y1_output_root_mean_squared_error: 0.6799 - val_y2_output_root_mean_squared_error: 1.2846
# Epoch 107/500
# 614/614 [==============================] - 0s 178us/sample - loss: 3.5730 - y1_output_loss: 0.9632 - y2_output_loss: 2.6628 - y1_output_root_mean_squared_error: 0.9688 - y2_output_root_mean_squared_error: 1.6231 - val_loss: 6.5807 - val_y1_output_loss: 2.2211 - val_y2_output_loss: 4.2292 - val_y1_output_root_mean_squared_error: 1.5124 - val_y2_output_root_mean_squared_error: 2.0721
# Epoch 108/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.8287 - y1_output_loss: 0.7664 - y2_output_loss: 2.1191 - y1_output_root_mean_squared_error: 0.8703 - y2_output_root_mean_squared_error: 1.4392 - val_loss: 9.0429 - val_y1_output_loss: 1.3462 - val_y2_output_loss: 7.5211 - val_y1_output_root_mean_squared_error: 1.1714 - val_y2_output_root_mean_squared_error: 2.7696
# Epoch 109/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.4999 - y1_output_loss: 0.5961 - y2_output_loss: 1.8951 - y1_output_root_mean_squared_error: 0.7681 - y2_output_root_mean_squared_error: 1.3820 - val_loss: 2.0870 - val_y1_output_loss: 0.5337 - val_y2_output_loss: 1.5640 - val_y1_output_root_mean_squared_error: 0.7129 - val_y2_output_root_mean_squared_error: 1.2565
# Epoch 110/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.5944 - y1_output_loss: 0.6117 - y2_output_loss: 1.9626 - y1_output_root_mean_squared_error: 0.7844 - y2_output_root_mean_squared_error: 1.4068 - val_loss: 2.5571 - val_y1_output_loss: 0.4563 - val_y2_output_loss: 2.1159 - val_y1_output_root_mean_squared_error: 0.6736 - val_y2_output_root_mean_squared_error: 1.4503
# Epoch 111/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.8399 - y1_output_loss: 0.6681 - y2_output_loss: 2.1477 - y1_output_root_mean_squared_error: 0.8206 - y2_output_root_mean_squared_error: 1.4719 - val_loss: 6.0568 - val_y1_output_loss: 2.2397 - val_y2_output_loss: 3.7444 - val_y1_output_root_mean_squared_error: 1.5064 - val_y2_output_root_mean_squared_error: 1.9462
# Epoch 112/500
# 614/614 [==============================] - 0s 183us/sample - loss: 3.3689 - y1_output_loss: 0.8294 - y2_output_loss: 2.5215 - y1_output_root_mean_squared_error: 0.9142 - y2_output_root_mean_squared_error: 1.5916 - val_loss: 4.7368 - val_y1_output_loss: 0.5692 - val_y2_output_loss: 4.1825 - val_y1_output_root_mean_squared_error: 0.7422 - val_y2_output_root_mean_squared_error: 2.0460
# Epoch 113/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.8850 - y1_output_loss: 0.6260 - y2_output_loss: 2.2332 - y1_output_root_mean_squared_error: 0.7942 - y2_output_root_mean_squared_error: 1.5014 - val_loss: 3.2750 - val_y1_output_loss: 0.7478 - val_y2_output_loss: 2.5809 - val_y1_output_root_mean_squared_error: 0.8540 - val_y2_output_root_mean_squared_error: 1.5955
# Epoch 114/500
# 614/614 [==============================] - 0s 159us/sample - loss: 1.8156 - y1_output_loss: 0.4297 - y2_output_loss: 1.4069 - y1_output_root_mean_squared_error: 0.6534 - y2_output_root_mean_squared_error: 1.1784 - val_loss: 2.1324 - val_y1_output_loss: 0.3902 - val_y2_output_loss: 1.7325 - val_y1_output_root_mean_squared_error: 0.6167 - val_y2_output_root_mean_squared_error: 1.3237
# Epoch 115/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.4746 - y1_output_loss: 0.5174 - y2_output_loss: 1.9496 - y1_output_root_mean_squared_error: 0.7204 - y2_output_root_mean_squared_error: 1.3984 - val_loss: 5.3805 - val_y1_output_loss: 1.3627 - val_y2_output_loss: 4.0365 - val_y1_output_root_mean_squared_error: 1.1666 - val_y2_output_root_mean_squared_error: 2.0049
# Epoch 116/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.0556 - y1_output_loss: 0.4559 - y2_output_loss: 1.5856 - y1_output_root_mean_squared_error: 0.6757 - y2_output_root_mean_squared_error: 1.2645 - val_loss: 2.1704 - val_y1_output_loss: 0.5008 - val_y2_output_loss: 1.6771 - val_y1_output_root_mean_squared_error: 0.7083 - val_y2_output_root_mean_squared_error: 1.2918
# Epoch 117/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.1024 - y1_output_loss: 0.7165 - y2_output_loss: 2.3993 - y1_output_root_mean_squared_error: 0.8490 - y2_output_root_mean_squared_error: 1.5432 - val_loss: 10.6475 - val_y1_output_loss: 2.1968 - val_y2_output_loss: 8.5374 - val_y1_output_root_mean_squared_error: 1.4782 - val_y2_output_root_mean_squared_error: 2.9090
# Epoch 118/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.3661 - y1_output_loss: 0.5136 - y2_output_loss: 1.8655 - y1_output_root_mean_squared_error: 0.7177 - y2_output_root_mean_squared_error: 1.3605 - val_loss: 4.8796 - val_y1_output_loss: 0.5326 - val_y2_output_loss: 4.3395 - val_y1_output_root_mean_squared_error: 0.7334 - val_y2_output_root_mean_squared_error: 2.0837
# Epoch 119/500
# 614/614 [==============================] - 0s 175us/sample - loss: 2.7462 - y1_output_loss: 0.5469 - y2_output_loss: 2.1872 - y1_output_root_mean_squared_error: 0.7425 - y2_output_root_mean_squared_error: 1.4815 - val_loss: 3.3042 - val_y1_output_loss: 0.9999 - val_y2_output_loss: 2.2984 - val_y1_output_root_mean_squared_error: 1.0008 - val_y2_output_root_mean_squared_error: 1.5175
# Epoch 120/500
# 614/614 [==============================] - 0s 177us/sample - loss: 2.4109 - y1_output_loss: 0.5698 - y2_output_loss: 1.8323 - y1_output_root_mean_squared_error: 0.7573 - y2_output_root_mean_squared_error: 1.3555 - val_loss: 4.2239 - val_y1_output_loss: 0.5821 - val_y2_output_loss: 3.6664 - val_y1_output_root_mean_squared_error: 0.7608 - val_y2_output_root_mean_squared_error: 1.9092
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 188us/sample - loss: 0.4812 - y1_output_loss: 0.1472 - y2_output_loss: 0.3347 - y1_output_root_mean_squared_error: 0.3853 - y2_output_root_mean_squared_error: 0.5768 - val_loss: 0.9164 - val_y1_output_loss: 0.1715 - val_y2_output_loss: 0.7685 - val_y1_output_root_mean_squared_error: 0.4176 - val_y2_output_root_mean_squared_error: 0.8614
# Epoch 462/500
# 614/614 [==============================] - 0s 213us/sample - loss: 0.4887 - y1_output_loss: 0.1646 - y2_output_loss: 0.3242 - y1_output_root_mean_squared_error: 0.4060 - y2_output_root_mean_squared_error: 0.5691 - val_loss: 0.7152 - val_y1_output_loss: 0.1459 - val_y2_output_loss: 0.5915 - val_y1_output_root_mean_squared_error: 0.3821 - val_y2_output_root_mean_squared_error: 0.7544
# Epoch 463/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.4197 - y1_output_loss: 0.1318 - y2_output_loss: 0.2867 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.5359 - val_loss: 0.7981 - val_y1_output_loss: 0.1162 - val_y2_output_loss: 0.7005 - val_y1_output_root_mean_squared_error: 0.3472 - val_y2_output_root_mean_squared_error: 0.8231
# Epoch 464/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.4255 - y1_output_loss: 0.1431 - y2_output_loss: 0.2806 - y1_output_root_mean_squared_error: 0.3788 - y2_output_root_mean_squared_error: 0.5311 - val_loss: 0.6277 - val_y1_output_loss: 0.1389 - val_y2_output_loss: 0.5197 - val_y1_output_root_mean_squared_error: 0.3752 - val_y2_output_root_mean_squared_error: 0.6978
# Epoch 465/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4571 - y1_output_loss: 0.1372 - y2_output_loss: 0.3240 - y1_output_root_mean_squared_error: 0.3718 - y2_output_root_mean_squared_error: 0.5647 - val_loss: 2.9367 - val_y1_output_loss: 0.3333 - val_y2_output_loss: 2.6307 - val_y1_output_root_mean_squared_error: 0.5805 - val_y2_output_root_mean_squared_error: 1.6123
# Epoch 466/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4681 - y1_output_loss: 0.1367 - y2_output_loss: 0.3340 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5758 - val_loss: 1.1350 - val_y1_output_loss: 0.1650 - val_y2_output_loss: 0.9891 - val_y1_output_root_mean_squared_error: 0.4100 - val_y2_output_root_mean_squared_error: 0.9833
# Epoch 467/500
# 614/614 [==============================] - 0s 185us/sample - loss: 1.3451 - y1_output_loss: 0.3534 - y2_output_loss: 0.9803 - y1_output_root_mean_squared_error: 0.5970 - y2_output_root_mean_squared_error: 0.9943 - val_loss: 0.6575 - val_y1_output_loss: 0.1230 - val_y2_output_loss: 0.5905 - val_y1_output_root_mean_squared_error: 0.3520 - val_y2_output_root_mean_squared_error: 0.7304
# Epoch 468/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.4341 - y1_output_loss: 0.1260 - y2_output_loss: 0.3061 - y1_output_root_mean_squared_error: 0.3565 - y2_output_root_mean_squared_error: 0.5541 - val_loss: 0.8831 - val_y1_output_loss: 0.2221 - val_y2_output_loss: 0.6768 - val_y1_output_root_mean_squared_error: 0.4801 - val_y2_output_root_mean_squared_error: 0.8079
# Epoch 469/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.6311 - y1_output_loss: 0.1801 - y2_output_loss: 0.4498 - y1_output_root_mean_squared_error: 0.4241 - y2_output_root_mean_squared_error: 0.6717 - val_loss: 0.8107 - val_y1_output_loss: 0.1699 - val_y2_output_loss: 0.6506 - val_y1_output_root_mean_squared_error: 0.4184 - val_y2_output_root_mean_squared_error: 0.7972
# Epoch 470/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4211 - y1_output_loss: 0.1323 - y2_output_loss: 0.2909 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5376 - val_loss: 0.8793 - val_y1_output_loss: 0.1772 - val_y2_output_loss: 0.7171 - val_y1_output_root_mean_squared_error: 0.4282 - val_y2_output_root_mean_squared_error: 0.8342
# Epoch 471/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.3561 - y1_output_loss: 0.1231 - y2_output_loss: 0.2330 - y1_output_root_mean_squared_error: 0.3510 - y2_output_root_mean_squared_error: 0.4826 - val_loss: 1.1408 - val_y1_output_loss: 0.1323 - val_y2_output_loss: 1.0357 - val_y1_output_root_mean_squared_error: 0.3675 - val_y2_output_root_mean_squared_error: 1.0029
# Epoch 472/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3243 - y1_output_loss: 0.1176 - y2_output_loss: 0.2064 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.4548 - val_loss: 0.7565 - val_y1_output_loss: 0.1260 - val_y2_output_loss: 0.6467 - val_y1_output_root_mean_squared_error: 0.3606 - val_y2_output_root_mean_squared_error: 0.7915
# Epoch 473/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4355 - y1_output_loss: 0.1341 - y2_output_loss: 0.3007 - y1_output_root_mean_squared_error: 0.3662 - y2_output_root_mean_squared_error: 0.5489 - val_loss: 0.7488 - val_y1_output_loss: 0.1672 - val_y2_output_loss: 0.6009 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.7610
# Epoch 474/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3259 - y1_output_loss: 0.1261 - y2_output_loss: 0.2060 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.4510 - val_loss: 1.5488 - val_y1_output_loss: 0.1361 - val_y2_output_loss: 1.4189 - val_y1_output_root_mean_squared_error: 0.3747 - val_y2_output_root_mean_squared_error: 1.1867
# Epoch 475/500
# 614/614 [==============================] - 0s 180us/sample - loss: 0.4558 - y1_output_loss: 0.1291 - y2_output_loss: 0.3350 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.5710 - val_loss: 0.9707 - val_y1_output_loss: 0.1266 - val_y2_output_loss: 0.8752 - val_y1_output_root_mean_squared_error: 0.3622 - val_y2_output_root_mean_squared_error: 0.9163
# Epoch 476/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4526 - y1_output_loss: 0.1286 - y2_output_loss: 0.3212 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.5691 - val_loss: 0.6912 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.5060 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.6979
# Epoch 477/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4051 - y1_output_loss: 0.1288 - y2_output_loss: 0.2777 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5270 - val_loss: 0.9620 - val_y1_output_loss: 0.1962 - val_y2_output_loss: 0.7577 - val_y1_output_root_mean_squared_error: 0.4489 - val_y2_output_root_mean_squared_error: 0.8721
# Epoch 478/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.6055 - y1_output_loss: 0.1819 - y2_output_loss: 0.4206 - y1_output_root_mean_squared_error: 0.4273 - y2_output_root_mean_squared_error: 0.6503 - val_loss: 1.0069 - val_y1_output_loss: 0.1853 - val_y2_output_loss: 0.8403 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.9047
# Epoch 479/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4861 - y1_output_loss: 0.1538 - y2_output_loss: 0.3327 - y1_output_root_mean_squared_error: 0.3928 - y2_output_root_mean_squared_error: 0.5761 - val_loss: 0.7061 - val_y1_output_loss: 0.2022 - val_y2_output_loss: 0.5229 - val_y1_output_root_mean_squared_error: 0.4526 - val_y2_output_root_mean_squared_error: 0.7080
# Epoch 480/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.4202 - y1_output_loss: 0.1378 - y2_output_loss: 0.2824 - y1_output_root_mean_squared_error: 0.3728 - y2_output_root_mean_squared_error: 0.5303 - val_loss: 1.0034 - val_y1_output_loss: 0.1522 - val_y2_output_loss: 0.8836 - val_y1_output_root_mean_squared_error: 0.3911 - val_y2_output_root_mean_squared_error: 0.9222
# Epoch 481/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4741 - y1_output_loss: 0.1357 - y2_output_loss: 0.3417 - y1_output_root_mean_squared_error: 0.3690 - y2_output_root_mean_squared_error: 0.5813 - val_loss: 2.3575 - val_y1_output_loss: 0.2320 - val_y2_output_loss: 2.1237 - val_y1_output_root_mean_squared_error: 0.4903 - val_y2_output_root_mean_squared_error: 1.4550
# Epoch 482/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.5314 - y1_output_loss: 0.1557 - y2_output_loss: 0.3785 - y1_output_root_mean_squared_error: 0.3939 - y2_output_root_mean_squared_error: 0.6134 - val_loss: 1.4240 - val_y1_output_loss: 0.3769 - val_y2_output_loss: 1.0645 - val_y1_output_root_mean_squared_error: 0.6141 - val_y2_output_root_mean_squared_error: 1.0232
# Epoch 483/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3944 - y1_output_loss: 0.1176 - y2_output_loss: 0.2752 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.5258 - val_loss: 1.0853 - val_y1_output_loss: 0.1365 - val_y2_output_loss: 0.9584 - val_y1_output_root_mean_squared_error: 0.3756 - val_y2_output_root_mean_squared_error: 0.9717
# Epoch 484/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3269 - y1_output_loss: 0.1179 - y2_output_loss: 0.2081 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 1.0797 - val_y1_output_loss: 0.1756 - val_y2_output_loss: 0.9140 - val_y1_output_root_mean_squared_error: 0.4235 - val_y2_output_root_mean_squared_error: 0.9489
# Epoch 485/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4108 - y1_output_loss: 0.1357 - y2_output_loss: 0.2731 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5246 - val_loss: 0.9394 - val_y1_output_loss: 0.2844 - val_y2_output_loss: 0.7036 - val_y1_output_root_mean_squared_error: 0.5284 - val_y2_output_root_mean_squared_error: 0.8125
# Epoch 486/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4505 - y1_output_loss: 0.1343 - y2_output_loss: 0.3183 - y1_output_root_mean_squared_error: 0.3669 - y2_output_root_mean_squared_error: 0.5620 - val_loss: 1.8307 - val_y1_output_loss: 0.2964 - val_y2_output_loss: 1.5427 - val_y1_output_root_mean_squared_error: 0.5510 - val_y2_output_root_mean_squared_error: 1.2358
# Epoch 487/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.5102 - y1_output_loss: 0.1293 - y2_output_loss: 0.3829 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.6169 - val_loss: 0.7136 - val_y1_output_loss: 0.1412 - val_y2_output_loss: 0.6066 - val_y1_output_root_mean_squared_error: 0.3795 - val_y2_output_root_mean_squared_error: 0.7547
# Epoch 488/500
# 614/614 [==============================] - 0s 190us/sample - loss: 0.3644 - y1_output_loss: 0.1313 - y2_output_loss: 0.2322 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.4816 - val_loss: 1.0624 - val_y1_output_loss: 0.1422 - val_y2_output_loss: 0.9287 - val_y1_output_root_mean_squared_error: 0.3837 - val_y2_output_root_mean_squared_error: 0.9567
# Epoch 489/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.5990 - y1_output_loss: 0.1326 - y2_output_loss: 0.4728 - y1_output_root_mean_squared_error: 0.3652 - y2_output_root_mean_squared_error: 0.6824 - val_loss: 4.2081 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 4.0603 - val_y1_output_root_mean_squared_error: 0.4427 - val_y2_output_root_mean_squared_error: 2.0030
# Epoch 490/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.4234 - y1_output_loss: 0.1272 - y2_output_loss: 0.2933 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5434 - val_loss: 0.6426 - val_y1_output_loss: 0.1915 - val_y2_output_loss: 0.4921 - val_y1_output_root_mean_squared_error: 0.4338 - val_y2_output_root_mean_squared_error: 0.6741
# Epoch 491/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4003 - y1_output_loss: 0.1327 - y2_output_loss: 0.2651 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.5163 - val_loss: 0.6043 - val_y1_output_loss: 0.1224 - val_y2_output_loss: 0.5049 - val_y1_output_root_mean_squared_error: 0.3530 - val_y2_output_root_mean_squared_error: 0.6926
# Epoch 492/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.4400 - y1_output_loss: 0.1420 - y2_output_loss: 0.2970 - y1_output_root_mean_squared_error: 0.3755 - y2_output_root_mean_squared_error: 0.5468 - val_loss: 0.6351 - val_y1_output_loss: 0.1751 - val_y2_output_loss: 0.4963 - val_y1_output_root_mean_squared_error: 0.4175 - val_y2_output_root_mean_squared_error: 0.6788
# Epoch 493/500
# 614/614 [==============================] - 0s 180us/sample - loss: 0.3307 - y1_output_loss: 0.1109 - y2_output_loss: 0.2183 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.4686 - val_loss: 0.6243 - val_y1_output_loss: 0.1615 - val_y2_output_loss: 0.4925 - val_y1_output_root_mean_squared_error: 0.4045 - val_y2_output_root_mean_squared_error: 0.6787
# Epoch 494/500
# 614/614 [==============================] - 0s 190us/sample - loss: 0.4385 - y1_output_loss: 0.1310 - y2_output_loss: 0.3049 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5541 - val_loss: 0.6542 - val_y1_output_loss: 0.1479 - val_y2_output_loss: 0.5185 - val_y1_output_root_mean_squared_error: 0.3897 - val_y2_output_root_mean_squared_error: 0.7087
# Epoch 495/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.3803 - y1_output_loss: 0.1385 - y2_output_loss: 0.2437 - y1_output_root_mean_squared_error: 0.3709 - y2_output_root_mean_squared_error: 0.4927 - val_loss: 0.7010 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.5281 - val_y1_output_root_mean_squared_error: 0.4594 - val_y2_output_root_mean_squared_error: 0.6999
# Epoch 496/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4447 - y1_output_loss: 0.1557 - y2_output_loss: 0.2929 - y1_output_root_mean_squared_error: 0.3928 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 1.0952 - val_y1_output_loss: 0.3319 - val_y2_output_loss: 0.7808 - val_y1_output_root_mean_squared_error: 0.5848 - val_y2_output_root_mean_squared_error: 0.8679
# Epoch 497/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4620 - y1_output_loss: 0.1557 - y2_output_loss: 0.3024 - y1_output_root_mean_squared_error: 0.3962 - y2_output_root_mean_squared_error: 0.5522 - val_loss: 0.6473 - val_y1_output_loss: 0.1512 - val_y2_output_loss: 0.5209 - val_y1_output_root_mean_squared_error: 0.3901 - val_y2_output_root_mean_squared_error: 0.7037
# Epoch 498/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.3580 - y1_output_loss: 0.1123 - y2_output_loss: 0.2442 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4953 - val_loss: 1.0087 - val_y1_output_loss: 0.2908 - val_y2_output_loss: 0.7845 - val_y1_output_root_mean_squared_error: 0.5364 - val_y2_output_root_mean_squared_error: 0.8491
# Epoch 499/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3169 - y1_output_loss: 0.1167 - y2_output_loss: 0.1987 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4469 - val_loss: 0.8052 - val_y1_output_loss: 0.1369 - val_y2_output_loss: 0.6900 - val_y1_output_root_mean_squared_error: 0.3763 - val_y2_output_root_mean_squared_error: 0.8146
# Epoch 500/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4167 - y1_output_loss: 0.1426 - y2_output_loss: 0.2707 - y1_output_root_mean_squared_error: 0.3792 - y2_output_root_mean_squared_error: 0.5224 - val_loss: 0.6773 - val_y1_output_loss: 0.1150 - val_y2_output_loss: 0.5840 - val_y1_output_root_mean_squared_error: 0.3449 - val_y2_output_root_mean_squared_error: 0.7472

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 41us/sample - loss: 0.6773 - y1_output_loss: 0.1177 - y2_output_loss: 0.5621 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.7472
# Loss = 0.6772561328751701, Y1_loss = 0.11772798001766205, Y1_mse = 0.34489402174949646, Y2_loss = 0.5621453523635864, Y2_mse = 0.7471975684165955

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
